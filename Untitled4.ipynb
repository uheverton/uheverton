# %% [markdown]
# <a href="https://colab.research.google.com/github/uheverton/uheverton/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Install colab-ssh
# !pip install colab-ssh --upgrade

from colab_ssh import launch_ssh_cloudflared

# Get a secure password from the user or set one programmatically
# For security, you should replace 'YOUR_SECURE_PASSWORD' with a strong password.
# You can also use `getpass.getpass()` for interactive password input.
password = "YOUR_SECURE_PASSWORD" # <-- ALTO: Por favor, substitua 'YOUR_SECURE_PASSWORD' por uma senha forte e segura!

# Launch the SSH tunnel
launch_ssh_cloudflared(password=password)

# %%
# No Colab - célula 1
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !apt-get install -y openssh-server > /dev/null 2>&1
# !service ssh start

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !apt-get install -y openssh-server > /dev/null 2>&1
# !echo "root:12345678" | chpasswd
# !mkdir -p /run/sshd
# !echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
# !echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config
# !service ssh start
# !echo "SSH rodando!"

# %%
# !./cloudflared-linux-amd64 tunnel --url tcp://localhost:22
